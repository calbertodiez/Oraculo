# %%
import pandas as pd
data = pd.read_csv('data_main.csv', sep=',', index_col = 0)

# %%
data
# Out:
#                                  persona_fecha_nacimiento  persona_latitud  \
# persona_id
# 00006dd34473b57128d6661907bf4fa3               1997-07-05         4.296846
# 00006dd34473b57128d6661907bf4fa3               1997-07-05         4.296846
# 00006dd34473b57128d6661907bf4fa3               1997-07-05         4.296846
# 0000700428fb4af4bfcf4c594b6b6834               1996-04-19         8.312416
# 0000700428fb4af4bfcf4c594b6b6834               1996-04-19         8.312416
# ...                                                   ...              ...
# root                                           1992-04-17         4.633220
# root                                           1992-04-17         4.633220
# root                                           1992-04-17         4.633220
# sitio_prueba                                   2000-01-01              NaN
# tavo                                           1987-02-02         4.633220
#
# ...

# %%
data.columns
# Out:
# Index(['persona_fecha_nacimiento', 'persona_latitud', 'persona_longitud',
#        'persona_genero', 'colaborardor_id', 'colaborador_calificacion',
#        'colaborador_nivel_academico', 'colaborador_ocupacion',
#        'colaborador_profesion', 'colaborador_semestre',
#        'colaborador_tipo_registro', 'colaborador_universidad',
#        'colaborador_interprete_senas', 'colaborador_lector_especializado',
#        'colaborador_apoyo_congnitivo', 'colaborador_correo_valido',
#        'colaborador_nivel_ingles', 'colaborador_estado_colaborador',
#        'asignacion_colaborador_id', 'nombre', 'asignacion_evento_nombre',
#        'asignacion_evento_descripcion', 'asignacion_evento_fecha_inicio',
#        'asignacion_evento_hora_inicio', 'asignacion_evento_fecha_fin',
#        'asignacion_evento_hora_fin',
#        'asignacion_evento_hora_inicio_asistencia',
#        'asignacion_evento_hora_inicio_cierre_sesion',
# ...

# %%
data['colaborador_calificacion'].unique()
# Out:
# array([ 0., nan])

# %%
data['colaborador_estado_colaborador'].unique()
# Out:
# array(['Aceptado', 'Aspirante', nan], dtype=object)

# %%
tabla = data.groupby(["colaborador_estado_colaborador"]).size()
print(tabla)
# Out:
# colaborador_estado_colaborador
# Aceptado     295541
# Aspirante     22324
# dtype: int64
